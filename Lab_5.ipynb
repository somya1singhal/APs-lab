# %% [markdown]
# <a href="https://colab.research.google.com/github/somya1singhal/APs-lab/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

def selection_sort(numbers):
    for i in range(len(numbers)):
        min_idx = i
        for j in range(i + 1, len(numbers)):
            if numbers[j] < numbers[min_idx]:
                min_idx = j
                numbers[i], numbers[min_idx] = numbers[min_idx], numbers[i]
    return numbers

def measure_running_time(sort_function, size):

    data = [random.randint(0, 10000) for _ in range(size)]

    start_time = time.time()
    sort_function(list(data))
    end_time = time.time()

    return end_time - start_time

def plot_running_times():
    sizes = [100, 500, 1000, 2000, 5000]
    times = []

    print("Measuring running times...")
    for size in sizes:
        time_taken = measure_running_time(selection_sort, size)
        times.append(time_taken)
        print(f"Size: {size}, Time: {time_taken:.4f} seconds")

    plt.figure(figsize=(8, 6))
    plt.plot(sizes, times, marker='o', linestyle='-', color='b')
    plt.title('Selection Sort Running Time vs. List Size')
    plt.xlabel('List Size (Number of Elements)')
    plt.ylabel('Time Taken (Seconds)')
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
    try:
        num_elements = int(input("Enter the number of elements for the list: "))
        if num_elements <= 0:
            print("Number of elements must be positive.")
        else:
            numbers_list = []
            for i in range(num_elements):
                element = int(input(f"Enter element {i + 1}: "))
                numbers_list.append(element)

            print(f"\nOriginal list: {numbers_list}")
            sorted_list = selection_sort(numbers_list)
            print(f"Sorted list: {sorted_list}")
            print("\nGenerating performance graph...")
            plot_running_times()

    except ValueError:
        print("Invalid input. Please enter integers for the number of elements and the elements themselves.")
# Out:
# Enter the number of elements for the list: 4
# Enter element 1: 5
# Enter element 2: 8
# Enter element 3: 2
# Enter element 4: 9
#
# Original list: [5, 8, 2, 9]
# Sorted list: [2, 5, 8, 9]
#
# Generating performance graph...
# Measuring running times...
# Size: 100, Time: 0.0002 seconds
# Size: 500, Time: 0.0065 seconds
# Size: 1000, Time: 0.0240 seconds
# Size: 2000, Time: 0.0943 seconds
# Size: 5000, Time: 0.6128 seconds

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]
        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1
        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1
    return arr
def measure_time(n):
    data = [random.randint(0, 1000000) for _ in range(n)]

    start_time = time.perf_counter()
    merge_sort(data)
    end_time = time.perf_counter()

    return end_time - start_time

def plot_timing_graph():
    input_sizes = [1000, 2000, 5000, 10000, 20000, 50000, 100000]
    times = []

    print("Measuring performance for different input sizes...")
    for n in input_sizes:
        average_time = sum(measure_time(n) for _ in range(3)) / 3
        times.append(average_time)
        print(f"n = {n}: Time = {average_time:.6f} seconds")
    plt.figure(figsize=(10, 6))
    plt.plot(input_sizes, times, marker='o', linestyle='-', color='b')
    plt.title('Merge Sort Time Complexity (Time vs. Input Size n)')
    plt.xlabel('Input Size (n)')
    plt.ylabel('Time (seconds)')
    plt.grid(True)
    plt.xscale('log')
    plt.yscale('log')
    plt.show()

if __name__ == "__main__":
    my_list = [12, 11, 13,8, 6, 7]
    print(f"Original list: {my_list}")
    sorted_list = merge_sort(my_list)
    print(f"Sorted list: {sorted_list}")
    print("-" * 30)
    plot_timing_graph()
# Out:
# Original list: [12, 11, 13, 8, 6, 7]
# Sorted list: [6, 7, 8, 11, 12, 13]
# ------------------------------
# Measuring performance for different input sizes...
# n = 1000: Time = 0.001779 seconds
# n = 2000: Time = 0.003695 seconds
# n = 5000: Time = 0.010654 seconds
# n = 10000: Time = 0.023442 seconds
# n = 20000: Time = 0.051533 seconds
# n = 50000: Time = 0.154203 seconds
# n = 100000: Time = 0.335159 seconds

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt
import sys
sys.setrecursionlimit(2000)
def quicksort(arr):
    if len(arr) <= 1:
        return arr
    else:
        pivot = arr[0]
        less = [x for x in arr[1:] if x <= pivot]
        greater = [x for x in arr[1:] if x > pivot]
        return quicksort(less) + [pivot] + quicksort(greater)
def measure_time(n):
    data = [random.randint(0, 10000) for _ in range(n)]
    start_time = time.time()
    quicksort(data)
    return time.time() - start_time
sizes = [100, 500, 1000, 2000, 3000, 4000, 5000]
times = [measure_time(n) for n in sizes]
plt.figure(figsize=(10, 6))
plt.plot(sizes, times, marker='o', linestyle='-', color='b')
plt.title('Quicksort Running Time ($O(n \log n)$ avg)')
plt.xlabel('Number of Elements (n)')
plt.ylabel('Time taken (seconds)')
plt.grid(True)
plt.show()
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\l'
# <>:25: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipython-input-2215607065.py:25: SyntaxWarning: invalid escape sequence '\l'
#   plt.title('Quicksort Running Time ($O(n \log n)$ avg)')

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[len(n_list) -1]

# %%
# Creating a random value (uniform)
import random
ms = datetime.now().microsecond / 1000
random.seed(ms)

numbers = []
for i in range(n_max):
    numbers.append(int(random.random() * 1000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1036474192.py in <cell line: 0>()
#       1 # Creating a random value (uniform)
#       2 import random
# ----> 3 ms = datetime.now().microsecond / 1000
#       4 random.seed(ms)
#       5
#
# NameError: name 'datetime' is not defined

# %%
a_time = []
b_time = []
c_time = []

for l in n_list:
    a = copy.deepcopy(numbers[0:l])
    b = copy.deepcopy(numbers[0:l])
    c = copy.deepcopy(numbers[0:l])

    start_time = timeit.default_timer()
    quick_sort(a)
    a_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    merge_sort(b)
    b_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    selection.sort()
    c_time.append((timeit.default_timer() - start_time) * 1000)

# %%
# Plotting results
plt.figure(figsize=(10, 5))
plt.plot(a_time, linewidth = 1, marker="o")
plt.plot(b_time, linewidth = 1, marker="o")
plt.plot(c_time, linewidth = 1, marker="o")
plt.xticks(np.arange(len(n_list)), n_list)
plt.title("Compare Sorting Algorithms", fontsize = 14)
plt.ylabel('Time (ms)')
plt.xlabel('n')
plt.legend(("Quicksort", "Mergesort", "Selection sort"), loc = "best")
plt.show()
